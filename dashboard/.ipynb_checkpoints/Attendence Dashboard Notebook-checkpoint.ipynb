# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load CSV
df = pd.read_csv(r"C:\Users\KIIT0001\OneDrive\Desktop\attendence_project\data\raw\attendance_details.csv")

# Preview
df.head()
# Out:
#    attendance_id  student_id  course_id attendance_date   status  \
# 0              1       12648       1960      2026-03-01  Present
# 1              2       25218       1670      2026-03-02   Absent
# 2              3       42995       1496      2026-03-04  Present
# 3              4       46889        575      2026-03-10  Present
# 4              5       12673        858      2026-03-08  Present
#
#            recorded_at
# 0  2026-04-18 17:23:03
# 1  2026-04-18 17:23:03
# 2  2026-04-18 17:23:03
# 3  2026-04-18 17:23:03
# 4  2026-04-18 17:23:03

# %%
print("Total Records:", len(df))
print("Present Count:", len(df[df["status"] == "Present"]))
print("Absent Count:", len(df[df["status"] == "Absent"]))
# Out:
# Total Records: 15000
# Present Count: 12055
# Absent Count: 2945

# %%
#Course-Wise Attendance
course_attendance = df.groupby("course_id")["status"].value_counts().unstack().fillna(0)

course_attendance
# Out:
# status     Absent  Present
# course_id
# 513            21      130
# 531            25      106
# 559            45      133
# 573            45      110
# 575            26      105
# ...           ...      ...
# 1951           25      125
# 1960           27      140
# 1974           31      115
# 1984           24      108
# 1987           37      141
#
# [100 rows x 2 columns]

# %%
course_attendance.plot(kind="bar", figsize=(8,5))

plt.title("Attendance per Course")
plt.xlabel("Course ID")
plt.ylabel("Count")
plt.xticks(rotation=0)

plt.show()

# %%
student_attendance = df.groupby("student_id")["status"].value_counts().unstack().fillna(0)

student_attendance["attendance_%"] = (
    student_attendance["Present"] /
    (student_attendance["Present"] + student_attendance["Absent"])
) * 100

student_attendance
# Out:
# status      Absent  Present  attendance_%
# student_id
# 100            0.0      3.0         100.0
# 131            1.0      0.0           0.0
# 142            0.0      2.0         100.0
# 159            1.0      0.0           0.0
# 165            0.0      2.0         100.0
# ...            ...      ...           ...
# 49969          0.0      2.0         100.0
# 49975          0.0      1.0         100.0
# 49986          1.0      1.0          50.0
# 49991          1.0      0.0           0.0
# 49998          1.0      1.0          50.0
#
# [7797 rows x 3 columns]

# %%
#Top 10 students by attendence%
top_students = student_attendance.sort_values("attendance_%", ascending=False).head(10)

top_students["attendance_%"].plot(kind="bar", figsize=(8,5))
plt.title("Top 10 Students by Attendance")
plt.xlabel("Student ID")
plt.ylabel("Attendance %")
plt.xticks(rotation=45)
plt.show()

# %%
# Highest attendance course
top_course = df[df["status"] == "Present"].groupby("course_id").size().idxmax()

# Most absent student
top_absent_student = df[df["status"] == "Absent"].groupby("student_id").size().idxmax()

print("Course with highest attendance:", top_course)
print("Most frequently absent student:", top_absent_student)
# Out:
# Course with highest attendance: 973
# Most frequently absent student: 24119

# %%
#Daily Attendance Trend
df["attendance_date"] = pd.to_datetime(df["attendance_date"])

daily_trend = df.groupby("attendance_date")["status"].value_counts().unstack().fillna(0)

daily_trend["attendance_%"] = (
    daily_trend.get("Present", 0) /
    (daily_trend.get("Present", 0) + daily_trend.get("Absent", 0))
) * 100

daily_trend["attendance_%"].plot(figsize=(10,5))
plt.title("Daily Attendance Trend")
plt.ylabel("Attendance %")
plt.show()

# %%
total_students = df["student_id"].nunique()
total_courses = df["course_id"].nunique()
overall_attendance = (df["status"] == "Present").mean() * 100

print("📊 KPI SUMMARY")
print("Total Students:", total_students)
print("Total Courses:", total_courses)
print("Overall Attendance %:", round(overall_attendance, 2))
# Out:
# 📊 KPI SUMMARY
# Total Students: 7797
# Total Courses: 100
# Overall Attendance %: 80.37

# %%
status_counts = df["status"].value_counts()

status_counts.plot(kind="pie", autopct="%1.1f%%", figsize=(6,6))
plt.title("Overall Attendance Distribution")
plt.ylabel("")
plt.show()
